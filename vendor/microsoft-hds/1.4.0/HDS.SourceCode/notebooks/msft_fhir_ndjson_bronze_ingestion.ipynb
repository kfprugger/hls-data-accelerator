# %% [markdown]
# #### Overview
#
# ### Features
# ##### Calling the BronzeIngestionService
#
# The foundation of Healthcare data solutions architecture is based on medallion architecture. In medallion architecture, data is processed using a multi-layered approach. The first layer is bronze which maintains the raw state of the data source. The second layer is silver which represents a validated, enriched version of our data. The third and final layer is gold which is highly refined and aggregated. In this notebook, we will ingest data into Delta tables in the `msft_bronze` lakehouse.
#
# Structure of the notebook:
# 1. **Load data and set up**: We begin by loading the necessary config details that you can specify.
# 2. **Call to BronzeIngestionService**: After setting up the prerequisites, we utilize the BronzeIngestion class to ingest the data.
# 3. **Verify results**: We can view the results of ingestion through a call to the newly created table.
#
# ### Configurations
# Prior to running this notebook, please ensure all configurations in the `msft_config_notebook` have been completed.
#
# ### Usage
# - Execute the notebook.
#
# _For more information and detailed steps see the [Healthcare data solutions Documentation](https://aka.ms/hds-doc)_

# %% [markdown]
# ##### Configuration management and setup
# The following cells will setup and manage configurations for the Healthcare data solutions:

# %%
# %run msft_config_notebook

# %%
# %run msft_config_notebook {"enable_spark_setup" : true, "enable_packages_mount" : false}

# %% [markdown]
# ##### Call to BronzeIngestionService
# After setting up the prerequisites, we utilize the BronzeIngestion class to ingest the data.
#
# It is currently configured to utilize the sample data that we have provided. If the sample data capability has not been deployed or you wish to utilize your own data, please update the `source_path_pattern` to the location of your own sample data.

# %% [markdown]
# `inline_params` is a json dictionary of parameters(configuration values) which will take precedence and be use in place of the configuration values in the administration lakehouse

# %%
inline_params = "{}"

# %%
from microsoft.fabric.hls.hds.services.bronze_ingestion_service import BronzeIngestionService
from microsoft.fabric.hls.hds.utils.utils import FolderPath
import json

# convert inline params into dictionary
inline_params_dict = json.loads(inline_params)

bronze_service = BronzeIngestionService(
        spark=spark,
        workspace_name=workspace_name,
        solution_name=solution_name,
        admin_lakehouse_name=administration_database_name,
        inline_params=inline_params_dict,
        one_lake_endpoint=one_lake_endpoint
)

bronze_service.run()

# %%
mssparkutils.fs.unmount(packages_mount_name)
