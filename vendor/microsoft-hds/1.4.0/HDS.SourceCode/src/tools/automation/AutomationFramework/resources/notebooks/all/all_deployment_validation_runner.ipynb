# %%
# %run hds_clinical_foundations_deployment_tests

# %%
# %run ci_deployment_tests

# %%
# %run claims_deployment_tests

# %%
# %run cma_deployment_tests

# %%
# %run dax_conversational_data_enrichments_deployment_tests

# %%
# %run imaging_deployment_tests

# %%
# %run omop_deployment_tests

# %%
# %run poa_deployment_tests

# %%
# %run sdoh_deployment_tests
